# %%
import csv
import requests

# 设置你的GitHub个人token
github_token = '#已注释'

# 读取CSV文件，CSV文件包含'actor_id'和'label'两列
csv_filename = 'github_bot_label_data.csv'
output_csv_filename = 'github_bot_raw_data.csv'  # 新的CSV文件

# 用于记录已处理的用户数量
processed_count = 0

# 检查是否存在保存进度的文件，如果存在，从中获取processed_count
progress_file = 'progress.txt'
try:
    with open(progress_file, 'r') as progress:
        processed_count = int(progress.read())
except FileNotFoundError:
    pass

# 打开CSV文件并创建新的CSV文件
with open(csv_filename, mode='r', newline='') as file, \
     open(output_csv_filename, mode='a', newline='', encoding='utf-8') as output_file:
    csv_reader = csv.DictReader(file)
    
    # 创建CSV写入器，并指定列名
    fieldnames = ['actor_id', 'label', 'login', 'id', 'node_id', 'avatar_url', 'gravatar_id', 'url', 'html_url',
                  'followers_url', 'following_url', 'gists_url', 'starred_url', 'subscriptions_url', 'organizations_url',
                  'repos_url', 'events_url', 'received_events_url', 'type', 'site_admin', 'name', 'company', 'blog',
                  'location', 'email', 'hireable', 'bio', 'twitter_username', 'public_repos', 'public_gists',
                  'followers', 'following', 'created_at', 'updated_at']
    csv_writer = csv.DictWriter(output_file, fieldnames=fieldnames)
    
    # 如果已经处理的数量大于0，将CSV写入器移到文件的正确位置
    if processed_count > 0:
        for _ in range(processed_count):
            next(csv_reader)  # 跳过已处理的行
    
    # 如果已经处理的数量大于0，将CSV写入器移到文件的正确位置
    csv_writer.writeheader()
    
    # 计数器
    count = 0
    
    for row in csv_reader:
        
        
        actor_id = row['actor_id']
        label = row['label']
        
        # 构建GitHub API请求URL
        user_url = f'https://api.github.com/user/{actor_id}'  # 注意URL的修改
        
        # 设置HTTP头部，包括你的GitHub个人token
        headers = {
            'Authorization': f'token {github_token}',
            'Accept': 'application/vnd.github.v3+json'
        }
        
        print(f'Processing actor_id: {actor_id}')
        
        # 发送请求获取用户信息
        user_response = requests.get(user_url, headers=headers)
        
        if user_response.status_code == 200:
            user_data = user_response.json()
            
            # 将信息写入新的CSV文件
            csv_writer.writerow({
                'actor_id': actor_id,
                'label': label,
                'login': user_data['login'],
                'id': user_data['id'],
                'node_id': user_data['node_id'],
                'avatar_url': user_data['avatar_url'],
                'gravatar_id': user_data['gravatar_id'],
                'url': user_data['url'],
                'html_url': user_data['html_url'],
                'followers_url': user_data['followers_url'],
                'following_url': user_data['following_url'],
                'gists_url': user_data['gists_url'],
                'starred_url': user_data['starred_url'],
                'subscriptions_url': user_data['subscriptions_url'],
                'organizations_url': user_data['organizations_url'],
                'repos_url': user_data['repos_url'],
                'events_url': user_data['events_url'],
                'received_events_url': user_data['received_events_url'],
                'type': user_data['type'],
                'site_admin': user_data['site_admin'],
                'name': user_data['name'],
                'company': user_data['company'],
                'blog': user_data['blog'],
                'location': user_data['location'],
                'email': user_data['email'],
                'hireable': user_data['hireable'],
                'bio': user_data['bio'],
                'twitter_username': user_data['twitter_username'],
                'public_repos': user_data['public_repos'],
                'public_gists': user_data['public_gists'],
                'followers': user_data['followers'],
                'following': user_data['following'],
                'created_at': user_data['created_at'],
                'updated_at': user_data['updated_at']
            })
            
            count += 1
            processed_count += 1
            if processed_count % 10 == 0:  # 每处理10个用户保存一次进度
                with open(progress_file, 'w') as progress:
                    progress.write(str(processed_count))
        else:
            print(f'Error processing actor_id: {actor_id}')
            print(user_response.status_code)
        
        print('------------------------------------')
    
    print(f'Processed {count} actor_ids')
# Out:
# Processing actor_id: 2606959
# ------------------------------------
# Processing actor_id: 3027310
# ------------------------------------
# Processing actor_id: 9423774
# ------------------------------------
# Processing actor_id: 2960492
# ------------------------------------
# Processing actor_id: 46681084
# ------------------------------------
# Processing actor_id: 36771401
# ------------------------------------
# Processing actor_id: 31901150
# ------------------------------------
# Processing actor_id: 79102
# ------------------------------------
# Processing actor_id: 16718781
# ------------------------------------
# Processing actor_id: 46564150
# ------------------------------------
# Processing actor_id: 24581081
# ------------------------------------
# Processing actor_id: 7117978
# ------------------------------------
# Processing actor_id: 13301940
# ------------------------------------
# Processing actor_id: 40892567
# ------------------------------------
# Processing actor_id: 75001577
# ------------------------------------
# Processing actor_id: 17950965
# ------------------------------------
# Processing actor_id: 25311884
# ------------------------------------
# Processing actor_id: 47790158
# ------------------------------------
# Processing actor_id: 63493438
# ------------------------------------
# Processing actor_id: 39779558
# ------------------------------------
# Processing actor_id: 500
# ------------------------------------
# Processing actor_id: 6727250
# ------------------------------------
# Processing actor_id: 20389726
# ------------------------------------
# Processing actor_id: 6537332
# ------------------------------------
# Processing actor_id: 565661
# ------------------------------------
# Processing actor_id: 27112484
# ------------------------------------
# Processing actor_id: 12696650
# ------------------------------------
# Processing actor_id: 3974108
# ------------------------------------
# Processing actor_id: 53064568
# ------------------------------------
# Processing actor_id: 3190488
# ------------------------------------
# Processing actor_id: 37334640
# ------------------------------------
# Processing actor_id: 60662775
# ------------------------------------
# Processing actor_id: 37855124
# ------------------------------------
# Processing actor_id: 2354108
# ------------------------------------
# Processing actor_id: 6771947
# ------------------------------------
# Processing actor_id: 12948692
# ------------------------------------
# Processing actor_id: 46231
# ------------------------------------
# Processing actor_id: 432127
# ------------------------------------
# Processing actor_id: 144884
# ------------------------------------
# Processing actor_id: 34349915
# ------------------------------------
# Processing actor_id: 8349537
# ------------------------------------
# Processing actor_id: 39011611
# ------------------------------------
# Processing actor_id: 4980711
# ------------------------------------
# Processing actor_id: 36490558
# ------------------------------------
# Processing actor_id: 5635476
# ------------------------------------
# Processing actor_id: 5668787
# ------------------------------------
# Processing actor_id: 54081388
# ------------------------------------
# Processing actor_id: 5633066
# ------------------------------------
# Processing actor_id: 3222928
# ------------------------------------
# Processing actor_id: 76961798
# ------------------------------------
# Processing actor_id: 16214023
# ------------------------------------
# Processing actor_id: 49693820
# ------------------------------------
# Processing actor_id: 1265995
# ------------------------------------
# Processing actor_id: 33906690
# ------------------------------------
# Processing actor_id: 30606887
# ------------------------------------
# Processing actor_id: 18677354
# ------------------------------------
# Processing actor_id: 119164
# ------------------------------------
# Processing actor_id: 26440463
# ------------------------------------
# Processing actor_id: 1512021
# ------------------------------------
# Processing actor_id: 89770411
# ------------------------------------
# Processing actor_id: 55310213
# ------------------------------------
# Processing actor_id: 5209952
# ------------------------------------
# Processing actor_id: 49127376
# ------------------------------------
# Processing actor_id: 4198115
# ------------------------------------
# Processing actor_id: 51391473
# ------------------------------------
# Processing actor_id: 26342317
# ------------------------------------
# Processing actor_id: 35768171
# ------------------------------------
# Processing actor_id: 22779605
# ------------------------------------
# Processing actor_id: 7128721
# ------------------------------------
# Processing actor_id: 8862693
# ------------------------------------
# Processing actor_id: 21194285
# ------------------------------------
# Processing actor_id: 41993974
# ------------------------------------
# Processing actor_id: 30045531
# ------------------------------------
# Processing actor_id: 72028011
# ------------------------------------
# Processing actor_id: 7223028
# ------------------------------------
# Processing actor_id: 1779249
# ------------------------------------
# Processing actor_id: 4790
# ------------------------------------
# Processing actor_id: 71083854
# ------------------------------------
# Processing actor_id: 1385770
# ------------------------------------
# Processing actor_id: 21261007
# ------------------------------------
# Processing actor_id: 22067021
# ------------------------------------
# Processing actor_id: 174662
# ------------------------------------
# Processing actor_id: 295709
# ------------------------------------
# Processing actor_id: 11542693
# ------------------------------------
# Processing actor_id: 738765
# ------------------------------------
# Processing actor_id: 40244233
# ------------------------------------
# Processing actor_id: 12393718
# ------------------------------------
# Processing actor_id: 40143
# ------------------------------------
# Processing actor_id: 666683
# ------------------------------------
# Processing actor_id: 85256266
# ------------------------------------
# Processing actor_id: 71294927
# ------------------------------------
# Processing actor_id: 54860867
# ------------------------------------
# Processing actor_id: 65395387
# ------------------------------------
# Processing actor_id: 866677
# ------------------------------------
# Processing actor_id: 10359577
# ------------------------------------
# Processing actor_id: 45374034
# ------------------------------------
# Processing actor_id: 6761856
# ------------------------------------
# Processing actor_id: 180551
# ------------------------------------
# Processing actor_id: 25694730
# ------------------------------------
# Processing actor_id: 12143653
# ------------------------------------
# Processing actor_id: 37855075
# ------------------------------------
# Processing actor_id: 13489381
# ------------------------------------
# Processing actor_id: 72609355
# ------------------------------------
# Processing actor_id: 26112239
# ------------------------------------
# Processing actor_id: 2604887
# ------------------------------------
# Processing actor_id: 4427160
# ------------------------------------
# Processing actor_id: 56610014
# ------------------------------------
# Processing actor_id: 249779
# ------------------------------------
# Processing actor_id: 909222
# ------------------------------------
# Processing actor_id: 1539046
# ------------------------------------
# Processing actor_id: 63261637
# ------------------------------------
# Processing actor_id: 7762949
# ------------------------------------
# Processing actor_id: 74506764
# ------------------------------------
# Processing actor_id: 22807629
# ------------------------------------
# Processing actor_id: 18018452
# ------------------------------------
# Processing actor_id: 53905247
# ------------------------------------
# Processing actor_id: 46801700
# ------------------------------------
# Processing actor_id: 89894075
# ------------------------------------
# Processing actor_id: 25559053
# ------------------------------------
# Processing actor_id: 1183
# ------------------------------------
# Processing actor_id: 32149596
# ------------------------------------
# Processing actor_id: 1134
# ------------------------------------
# Processing actor_id: 75508020
# ------------------------------------
# Processing actor_id: 34695204
# ------------------------------------
# Processing actor_id: 56873669
# ------------------------------------
# Processing actor_id: 22865991
# ------------------------------------
# Processing actor_id: 468751
# ------------------------------------
# Processing actor_id: 495429
# ------------------------------------
# Processing actor_id: 465629
# ------------------------------------
# Processing actor_id: 4984825
# ------------------------------------
# Processing actor_id: 8124021
# ------------------------------------
# Processing actor_id: 2046846
# ------------------------------------
# Processing actor_id: 4298407
# ------------------------------------
# Processing actor_id: 417981
# ------------------------------------
# Processing actor_id: 55560129
# ------------------------------------
# Processing actor_id: 10775043
# ------------------------------------
# Processing actor_id: 7897760
# ------------------------------------
# Processing actor_id: 5365358
# ------------------------------------
# Processing actor_id: 67733299
# ------------------------------------
# Processing actor_id: 622699
# ------------------------------------
# Processing actor_id: 285797
# ------------------------------------
# Processing actor_id: 108653
# ------------------------------------
# Processing actor_id: 6315466
# ------------------------------------
# Processing actor_id: 12432488
# ------------------------------------
# Processing actor_id: 54665036
# ------------------------------------
# Processing actor_id: 2349470
# ------------------------------------
# Processing actor_id: 1908873
# ------------------------------------
# Processing actor_id: 9613701
# ------------------------------------
# Processing actor_id: 955033
# ------------------------------------
# Processing actor_id: 18333116
# ------------------------------------
# Processing actor_id: 2114189
# ------------------------------------
# Processing actor_id: 2174564
# ------------------------------------
# Processing actor_id: 215030
# ------------------------------------
# Processing actor_id: 26566442
# ------------------------------------
# Processing actor_id: 45343541
# ------------------------------------
# Processing actor_id: 1676121
# ------------------------------------
# Processing actor_id: 1304918
# ------------------------------------
# Processing actor_id: 46776329
# ------------------------------------
# Processing actor_id: 58249729
# ------------------------------------
# Processing actor_id: 68746461
# ------------------------------------
# Processing actor_id: 7645362
# ------------------------------------
# Processing actor_id: 32812891
# ------------------------------------
# Processing actor_id: 59910950
# ------------------------------------
# Processing actor_id: 74645302
# ------------------------------------
# Processing actor_id: 8975114
# ------------------------------------
# Processing actor_id: 62093618
# ------------------------------------
# Processing actor_id: 18662871
# ------------------------------------
# Processing actor_id: 21175639
# ------------------------------------
# Processing actor_id: 215702
# ------------------------------------
# Processing actor_id: 54082712
# ------------------------------------
# Processing actor_id: 62978449
# ------------------------------------
# Processing actor_id: 2322354
# ------------------------------------
# Processing actor_id: 7167300
# ------------------------------------
# Processing actor_id: 3968443
# ------------------------------------
# Processing actor_id: 42625018
# ------------------------------------
# Processing actor_id: 66550865
# ------------------------------------
# Processing actor_id: 36558508
# ------------------------------------
# Processing actor_id: 47642099
# ------------------------------------
# Processing actor_id: 4038041
# ------------------------------------
# Processing actor_id: 3199183
# ------------------------------------
# Processing actor_id: 14831261
# ------------------------------------
# Processing actor_id: 2128464
# ------------------------------------
# Processing actor_id: 22739822
# ------------------------------------
# Processing actor_id: 654902
# ------------------------------------
# Processing actor_id: 6974902
# Error processing actor_id: 6974902
# 404
# ------------------------------------
# Processing actor_id: 3380016
# ------------------------------------
# Processing actor_id: 32544373
# ------------------------------------
# Processing actor_id: 129737
# ------------------------------------
# Processing actor_id: 13323303
# ------------------------------------
# Processing actor_id: 7675847
# ------------------------------------
# Processing actor_id: 26118465
# ------------------------------------
# Processing actor_id: 31324
# ------------------------------------
# Processing actor_id: 42296182
# ------------------------------------
# Processing actor_id: 6550035
# ------------------------------------
# Processing actor_id: 10861600
# ------------------------------------
# Processing actor_id: 8050853
# ------------------------------------
# Processing actor_id: 22508290
# ------------------------------------
# Processing actor_id: 187848
# ------------------------------------
# Processing actor_id: 36027403
# ------------------------------------
# Processing actor_id: 28524381
# ------------------------------------
# Processing actor_id: 15524035
# ------------------------------------
# Processing actor_id: 6806011
# ------------------------------------
# Processing actor_id: 62853952
# ------------------------------------
# Processing actor_id: 63473496
# ------------------------------------
# Processing actor_id: 63029101
# ------------------------------------
# Processing actor_id: 1755362
# ------------------------------------
# Processing actor_id: 376455
# ------------------------------------
# Processing actor_id: 7872329
# ------------------------------------
# Processing actor_id: 3468483
# ------------------------------------
# Processing actor_id: 54312959
# ------------------------------------
# Processing actor_id: 76584243
# ------------------------------------
# Processing actor_id: 1907413
# ------------------------------------
# Processing actor_id: 303487
# ------------------------------------
# Processing actor_id: 4563792
# ------------------------------------
# Processing actor_id: 52682268
# ------------------------------------
# Processing actor_id: 63816999
# ------------------------------------
# Processing actor_id: 1542409
# ------------------------------------
# Processing actor_id: 78213164
# ------------------------------------
# Processing actor_id: 84067571
# ------------------------------------
# Processing actor_id: 6706544
# ------------------------------------
# Processing actor_id: 1936895
# ------------------------------------
# Processing actor_id: 2315673
# ------------------------------------
# Processing actor_id: 54591257
# ------------------------------------
# Processing actor_id: 66651997
# ------------------------------------
# Processing actor_id: 8864000
# ------------------------------------
# Processing actor_id: 12817816
# ------------------------------------
# Processing actor_id: 4971975
# ------------------------------------
# Processing actor_id: 16985475
# ------------------------------------
# Processing actor_id: 44570539
# ------------------------------------
# Processing actor_id: 21358010
# ------------------------------------
# Processing actor_id: 1317792
# ------------------------------------
# Processing actor_id: 845983
# ------------------------------------
# Processing actor_id: 15823519
# ------------------------------------
# Processing actor_id: 73139402
# ------------------------------------
# Processing actor_id: 20194490
# ------------------------------------
# Processing actor_id: 23625821
# ------------------------------------
# Processing actor_id: 11766139
# ------------------------------------
# Processing actor_id: 352441
# ------------------------------------
# Processing actor_id: 37937762
# ------------------------------------
# Processing actor_id: 1408600
# ------------------------------------
# Processing actor_id: 29553947
# ------------------------------------
# Processing actor_id: 45637986
# ------------------------------------
# Processing actor_id: 78701779
# ------------------------------------
# Processing actor_id: 55827009
# ------------------------------------
# Processing actor_id: 6594915
# ------------------------------------
# Processing actor_id: 1460122
# ------------------------------------
# Processing actor_id: 68362169
# ------------------------------------
# Processing actor_id: 4687791
# ------------------------------------
# Processing actor_id: 3914230
# ------------------------------------
# Processing actor_id: 51150235
# ------------------------------------
# Processing actor_id: 831648
# ------------------------------------
# Processing actor_id: 59071
# ------------------------------------
# Processing actor_id: 9455094
# ------------------------------------
# Processing actor_id: 9286933
# ------------------------------------
# Processing actor_id: 17270325
# ------------------------------------
# Processing actor_id: 8751635
# ------------------------------------
# Processing actor_id: 51506086
# ------------------------------------
# Processing actor_id: 472311
# ------------------------------------
# Processing actor_id: 13859395
# ------------------------------------
# Processing actor_id: 7804791
# ------------------------------------
# Processing actor_id: 79815764
# ------------------------------------
# Processing actor_id: 18269707
# ------------------------------------
# Processing actor_id: 49533950
# ------------------------------------
# Processing actor_id: 987136
# ------------------------------------
# Processing actor_id: 21292037
# ------------------------------------
# Processing actor_id: 35702532
# ------------------------------------
# Processing actor_id: 48600411
# ------------------------------------
# Processing actor_id: 53217558
# ------------------------------------
# Processing actor_id: 5799331
# ------------------------------------
# Processing actor_id: 3598852
# ------------------------------------
# Processing actor_id: 19857467
# ------------------------------------
# Processing actor_id: 36754821
# ------------------------------------
# Processing actor_id: 65553080
# ------------------------------------
# Processing actor_id: 3002344
# ------------------------------------
# Processing actor_id: 505046
# ------------------------------------
# Processing actor_id: 76971465
# ------------------------------------
# Processing actor_id: 12678528
# ------------------------------------
# Processing actor_id: 13513812
# ------------------------------------
# Processing actor_id: 22216761
# ------------------------------------
# Processing actor_id: 40526986
# ------------------------------------
# Processing actor_id: 31410839
# ------------------------------------
# Processing actor_id: 395641
# ------------------------------------
# Processing actor_id: 271966
# ------------------------------------
# Processing actor_id: 20182680
# ------------------------------------
# Processing actor_id: 82119979
# ------------------------------------
# Processing actor_id: 434655
# ------------------------------------
# Processing actor_id: 25405787
# ------------------------------------
# Processing actor_id: 48117473
# ------------------------------------
# Processing actor_id: 22001478
# ------------------------------------
# Processing actor_id: 11571300
# ------------------------------------
# Processing actor_id: 17916609
# ------------------------------------
# Processing actor_id: 16418547
# ------------------------------------
# Processing actor_id: 6377684
# ------------------------------------
# Processing actor_id: 845552
# ------------------------------------
# Processing actor_id: 66076021
# ------------------------------------
# Processing actor_id: 21308003
# ------------------------------------
# Processing actor_id: 61630653
# ------------------------------------
# Processing actor_id: 234708
# ------------------------------------
# Processing actor_id: 121129
# ------------------------------------
# Processing actor_id: 54043106
# ------------------------------------
# Processing actor_id: 7855765
# ------------------------------------
# Processing actor_id: 1122389
# ------------------------------------
# Processing actor_id: 63282184
# ------------------------------------
# Processing actor_id: 20305734
# ------------------------------------
# Processing actor_id: 61279246
# ------------------------------------
# Processing actor_id: 3599813
# ------------------------------------
# Processing actor_id: 6766851
# ------------------------------------
# Processing actor_id: 351553
# ------------------------------------
# Processing actor_id: 25178594
# ------------------------------------
# Processing actor_id: 10153298
# ------------------------------------
# Processing actor_id: 516118
# ------------------------------------
# Processing actor_id: 278988
# ------------------------------------
# Processing actor_id: 2159629
# ------------------------------------
# Processing actor_id: 66250972
# ------------------------------------
# Processing actor_id: 81188
# ------------------------------------
# Processing actor_id: 3713580
# ------------------------------------
# Processing actor_id: 48654350
# ------------------------------------
# Processing actor_id: 93940821
# ------------------------------------
# Processing actor_id: 1957806
# ------------------------------------
# Processing actor_id: 59826753
# ------------------------------------
# Processing actor_id: 24736507
# ------------------------------------
# Processing actor_id: 5551758
# ------------------------------------
# Processing actor_id: 28789723
# ------------------------------------
# Processing actor_id: 77425744
# ------------------------------------
# Processing actor_id: 75058881
# ------------------------------------
# Processing actor_id: 42699471
# ------------------------------------
# Processing actor_id: 88904
# ------------------------------------
# Processing actor_id: 25494577
# ------------------------------------
# Processing actor_id: 20694532
# ------------------------------------
# Processing actor_id: 26888375
# ------------------------------------
# Processing actor_id: 16906199
# ------------------------------------
# Processing actor_id: 37012961
# ------------------------------------
# Processing actor_id: 69001827
# ------------------------------------
# Processing actor_id: 24516654
# ------------------------------------
# Processing actor_id: 20234
# ------------------------------------
# Processing actor_id: 120810
# ------------------------------------
# Processing actor_id: 12854129
# ------------------------------------
# Processing actor_id: 61319150
# ------------------------------------
# Processing actor_id: 17502689
# ------------------------------------
# Processing actor_id: 413772
# ------------------------------------
# Processing actor_id: 55404786
# ------------------------------------
# Processing actor_id: 2594236
# ------------------------------------
# Processing actor_id: 7195563
# ------------------------------------
# Processing actor_id: 68724349
# ------------------------------------
# Processing actor_id: 12075600
# ------------------------------------
# Processing actor_id: 70960898
# ------------------------------------
# Processing actor_id: 335541
# ------------------------------------
# Processing actor_id: 20752424
# ------------------------------------
# Processing actor_id: 3849072
# ------------------------------------
# Processing actor_id: 4021595
# ------------------------------------
# Processing actor_id: 38477514
# ------------------------------------
# Processing actor_id: 6112010
# ------------------------------------
# Processing actor_id: 22045163
# ------------------------------------
# Processing actor_id: 39034242
# ------------------------------------
# Processing actor_id: 3538226
# ------------------------------------
# Processing actor_id: 16936
# ------------------------------------
# Processing actor_id: 15659410
# ------------------------------------
# Processing actor_id: 4312414
# ------------------------------------
# Processing actor_id: 64969005
# ------------------------------------
# Processing actor_id: 1799054
# ------------------------------------
# Processing actor_id: 14037268
# ------------------------------------
# Processing actor_id: 920512
# ------------------------------------
# Processing actor_id: 46193371
# ------------------------------------
# Processing actor_id: 10329648
# ------------------------------------
# Processing actor_id: 32783916
# ------------------------------------
# Processing actor_id: 48603081
# ------------------------------------
# Processing actor_id: 21693654
# ------------------------------------
# Processing actor_id: 43588962
# ------------------------------------
# Processing actor_id: 50598611
# ------------------------------------
# Processing actor_id: 7945706
# ------------------------------------
# Processing actor_id: 13176361
# ------------------------------------
# Processing actor_id: 9994529
# ------------------------------------
# Processing actor_id: 51362316
# ------------------------------------
# Processing actor_id: 24732563
# ------------------------------------
# Processing actor_id: 3030003
# ------------------------------------
# Processing actor_id: 33806646
# ------------------------------------
# Processing actor_id: 30500175
# ------------------------------------
# Processing actor_id: 10523218
# ------------------------------------
# Processing actor_id: 61765381
# ------------------------------------
# Processing actor_id: 19979279
# ------------------------------------
# Processing actor_id: 9317857
# ------------------------------------
# Processing actor_id: 56016372
# ------------------------------------
# Processing actor_id: 1372918
# ------------------------------------
# Processing actor_id: 4258778
# ------------------------------------
# Processing actor_id: 29749331
# ------------------------------------
# Processing actor_id: 9460939
# ------------------------------------
# Processing actor_id: 26720499
# ------------------------------------
# Processing actor_id: 9265252
# ------------------------------------
# Processing actor_id: 63709820
# ------------------------------------
# Processing actor_id: 66074607
# ------------------------------------
# Processing actor_id: 65845077
# ------------------------------------
# Processing actor_id: 27495990
# ------------------------------------
# Processing actor_id: 265630
# ------------------------------------
# Processing actor_id: 45324641
# ------------------------------------
# Processing actor_id: 42042535
# ------------------------------------
# Processing actor_id: 70376
# ------------------------------------
# Processing actor_id: 755842
# ------------------------------------
# Processing actor_id: 16844216
# ------------------------------------
# Processing actor_id: 3188890
# ------------------------------------
# Processing actor_id: 4331184
# ------------------------------------
# Processing actor_id: 35607980
# ------------------------------------
# Processing actor_id: 14330603
# ------------------------------------
# Processing actor_id: 50034602
# ------------------------------------
# Processing actor_id: 39601801
# ------------------------------------
# Processing actor_id: 73152
# ------------------------------------
# Processing actor_id: 25516241
# ------------------------------------
# Processing actor_id: 1240270
# ------------------------------------
# Processing actor_id: 4987327
# ------------------------------------
# Processing actor_id: 6177433
# ------------------------------------
# Processing actor_id: 69329190
# ------------------------------------
# Processing actor_id: 52562448
# ------------------------------------
# Processing actor_id: 70672236
# ------------------------------------
# Processing actor_id: 3165635
# ------------------------------------
# Processing actor_id: 30351955
# ------------------------------------
# Processing actor_id: 59104634
# ------------------------------------
# Processing actor_id: 2217102
# ------------------------------------
# Processing actor_id: 18407643
# ------------------------------------
# Processing actor_id: 14105827
# ------------------------------------
# Processing actor_id: 22769314
# ------------------------------------
# Processing actor_id: 1086317
# ------------------------------------
# Processing actor_id: 27334172
# ------------------------------------
# Processing actor_id: 4344253
# ------------------------------------
# Processing actor_id: 51863389
# ------------------------------------
# Processing actor_id: 11355520
# ------------------------------------
# Processing actor_id: 18445932
# ------------------------------------
# Processing actor_id: 71743241
# ------------------------------------
# Processing actor_id: 1751238
# ------------------------------------
# Processing actor_id: 7192338
# ------------------------------------
# Processing actor_id: 33176108
# ------------------------------------
# Processing actor_id: 28299531
# ------------------------------------
# Processing actor_id: 29734292
# ------------------------------------
# Processing actor_id: 73771796
# ------------------------------------
# Processing actor_id: 75124422
# ------------------------------------
# Processing actor_id: 13461315
# ------------------------------------
# Processing actor_id: 1405026
# ------------------------------------
# Processing actor_id: 19366641
# ------------------------------------
# Processing actor_id: 53030124
# ------------------------------------
# Processing actor_id: 35545007
# ------------------------------------
# Processing actor_id: 26427004
# ------------------------------------
# Processing actor_id: 4024711
# ------------------------------------
# Processing actor_id: 9993
# ------------------------------------
# Processing actor_id: 1128876
# ------------------------------------
# Processing actor_id: 19530785
# ------------------------------------
# Processing actor_id: 3286652
# ------------------------------------
# Processing actor_id: 10202888
# ------------------------------------
# Processing actor_id: 555154
# ------------------------------------
# Processing actor_id: 444071
# ------------------------------------
# Processing actor_id: 12776547
# ------------------------------------
# Processing actor_id: 47187177
# ------------------------------------
# Processing actor_id: 372735
# ------------------------------------
# Processing actor_id: 1413534
# ------------------------------------
# Processing actor_id: 4395417
# ------------------------------------
# Processing actor_id: 24444246
# ------------------------------------
# Processing actor_id: 606594
# ------------------------------------
# Processing actor_id: 29811106
# ------------------------------------
# Processing actor_id: 70013567
# ------------------------------------
# Processing actor_id: 14061824
# ------------------------------------
# Processing actor_id: 37411558
# ------------------------------------
# Processing actor_id: 2552837
# ------------------------------------
# Processing actor_id: 46508035
# ------------------------------------
# Processing actor_id: 639900
# ------------------------------------
# Processing actor_id: 6111424
# ------------------------------------
# Processing actor_id: 26144289
# ------------------------------------
# Processing actor_id: 50554310
# ------------------------------------
# Processing actor_id: 8220938
# ------------------------------------
# Processing actor_id: 43237426
# ------------------------------------
# Processing actor_id: 221582
# ------------------------------------
# Processing actor_id: 70930322
# ------------------------------------
# Processing actor_id: 3665167
# ------------------------------------
# Processing actor_id: 65603201
# ------------------------------------
# Processing actor_id: 7756211
# ------------------------------------
# Processing actor_id: 70461117
# ------------------------------------
# Processing actor_id: 44103947
# ------------------------------------
# Processing actor_id: 60074297
# ------------------------------------
# Processing actor_id: 54374648
# ------------------------------------
# Processing actor_id: 44160838
# ------------------------------------
# Processing actor_id: 21327264
# ------------------------------------
# Processing actor_id: 7685462
# ------------------------------------
# Processing actor_id: 1120596
# ------------------------------------
# Processing actor_id: 25270127
# ------------------------------------
# Processing actor_id: 1904967
# ------------------------------------
# Processing actor_id: 8757169
# ------------------------------------
# Processing actor_id: 2212006
# ------------------------------------
# Processing actor_id: 1966555
# ------------------------------------
# Processing actor_id: 17143038
# ------------------------------------
# Processing actor_id: 2065352
# ------------------------------------
# Processing actor_id: 33057997
# ------------------------------------
# Processing actor_id: 21292343
# ------------------------------------
# Processing actor_id: 5502029
# ------------------------------------
# Processing actor_id: 67918504
# ------------------------------------
# Processing actor_id: 1254693
# ------------------------------------
# Processing actor_id: 66223664
# ------------------------------------
# Processing actor_id: 3300381
# ------------------------------------
# Processing actor_id: 1687918
# ------------------------------------
# Processing actor_id: 59682018
# ------------------------------------
# Processing actor_id: 54890287
# ------------------------------------
# Processing actor_id: 54004431
# ------------------------------------
# Processing actor_id: 681390
# ------------------------------------
# Processing actor_id: 9073706
# ------------------------------------
# Processing actor_id: 2806645
# ------------------------------------
# Processing actor_id: 5239883
# ------------------------------------
# Processing actor_id: 18604620
# ------------------------------------
# Processing actor_id: 16150887
# ------------------------------------
# Processing actor_id: 624195
# ------------------------------------
# Processing actor_id: 23242101
# ------------------------------------
# Processing actor_id: 58790750
# ------------------------------------
# Processing actor_id: 25089914
# ------------------------------------
# Processing actor_id: 3837437
# ------------------------------------
# Processing actor_id: 36676045
# ------------------------------------
# Processing actor_id: 7426149
# ------------------------------------
# Processing actor_id: 27117322
# ------------------------------------
# Processing actor_id: 36554050
# ------------------------------------
# Processing actor_id: 29442812
# ------------------------------------
# Processing actor_id: 46922385
# ------------------------------------
# Processing actor_id: 66930949
# ------------------------------------
# Processing actor_id: 57676739
# ------------------------------------
# Processing actor_id: 31984694
# ------------------------------------
# Processing actor_id: 10090014
# ------------------------------------
# Processing actor_id: 54048360
# ------------------------------------
# Processing actor_id: 55693772
# ------------------------------------
# Processing actor_id: 1673303
# ------------------------------------
# Processing actor_id: 13562139
# ------------------------------------
# Processing actor_id: 35673267
# ------------------------------------
# Processing actor_id: 13561988
# ------------------------------------
# Processing actor_id: 102575
# ------------------------------------
# Processing actor_id: 16266103
# ------------------------------------
# Processing actor_id: 1728490
# ------------------------------------
# Processing actor_id: 79846533
# ------------------------------------
# Processing actor_id: 3003404
# ------------------------------------
# Processing actor_id: 34317373
# ------------------------------------
# Processing actor_id: 784742
# ------------------------------------
# Processing actor_id: 1256531
# ------------------------------------
# Processing actor_id: 29026887
# ------------------------------------
# Processing actor_id: 37890026
# ------------------------------------
# Processing actor_id: 1795691
# ------------------------------------
# Processing actor_id: 10425218
# ------------------------------------
# Processing actor_id: 40923967
# ------------------------------------
# Processing actor_id: 2342687
# ------------------------------------
# Processing actor_id: 8488446
# ------------------------------------
# Processing actor_id: 658691
# ------------------------------------
# Processing actor_id: 12472917
# ------------------------------------
# Processing actor_id: 4754931
# ------------------------------------
# Processing actor_id: 40847847
# ------------------------------------
# Processing actor_id: 22409868
# ------------------------------------
# Processing actor_id: 10203229
# ------------------------------------
# Processing actor_id: 25312957
# ------------------------------------
# Processing actor_id: 69195262
# ------------------------------------
# Processing actor_id: 1223135
# ------------------------------------
# Processing actor_id: 54113654
# ------------------------------------
# Processing actor_id: 10372036
# ------------------------------------
# Processing actor_id: 111974
# ------------------------------------
# Processing actor_id: 12577557
# ------------------------------------
# Processing actor_id: 2749938
# ------------------------------------
# Processing actor_id: 59517351
# ------------------------------------
# Processing actor_id: 1923070
# ------------------------------------
# Processing actor_id: 88939244
# ------------------------------------
# Processing actor_id: 6270979
# ------------------------------------
# Processing actor_id: 858731
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 64
#      61 print(f'Processing actor_id: {actor_id}')
#      63 # 发送请求获取用户信息
# ---> 64 user_response = requests.get(user_url, headers=headers)
#      66 if user_response.status_code == 200:
#      67     user_data = user_response.json()
#
# File D:\anaconda\res\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File D:\anaconda\res\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File D:\anaconda\res\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File D:\anaconda\res\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File D:\anaconda\res\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File D:\anaconda\res\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File D:\anaconda\res\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File D:\anaconda\res\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File D:\anaconda\res\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File D:\anaconda\res\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File D:\anaconda\res\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File D:\anaconda\res\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File D:\anaconda\res\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File D:\anaconda\res\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
